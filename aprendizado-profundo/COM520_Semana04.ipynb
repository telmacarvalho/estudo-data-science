# %% [markdown]
# <a href="https://colab.research.google.com/github/telmacarvalho/estudo-data-science/blob/main/aprendizado-profundo/COM520_Semana04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COM520 - Aprendizado Profundo
#
# ## Exercício de Apoio - Semana 04
#
# ### Autoencoders com o MNIST
#
# - Carregamento dos pacotes necessários
# - Carregamento dos dados (MNIST)
# - Modelo Raso
# - Modelo Profundo
#
# <!-- Observações:
# - ativar a GPU (Menu [Runtime], opção [Change runtime type])
# - Sem GPU, a execução deste caderno pode levar mais de 40 minutos. -->

# %% [markdown]
# ## Autoencoders
#
# <img src="https://blog.keras.io/img/ae/autoencoder_schema.jpg">
#
# Estrutura padrão de um autoencoder:
# - Camada de Codificação (Encoder)
# - Camada de Decodificação (Decoder)
# - Espaço Latente
#
# Fonte (imagem e código): https://blog.keras.io/building-autoencoders-in-keras.html

# %% [markdown]
# ## Pacotes

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
import keras.datasets as kds

import numpy as np
import matplotlib.pyplot as plt

# Bibliotecas utilizadas para projeção / redução de dimensionalidade
from sklearn.manifold import TSNE
from sklearn.decomposition import KernelPCA, PCA

# %% [markdown]
# ## Carregamento dos dados (MNIST)
#
# ### MNIST-Fashion
#
# Fonte: https://en.wikipedia.org/wiki/MNIST_database
#
# No Keras: https://keras.io/api/datasets/mnist/
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/27/MnistExamples.png">

# %%
num_classes = 10
input_shape = (28, 28, 1)

# Carga dos dados (keras.datasets)
(x_train, y_train), (x_test, y_test) = kds.mnist.load_data()

# Normalização das features
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 784)
# (10000, 784)

# %%
plt.figure(figsize=(12, 8))
for i in range(24):
    ax = plt.subplot(4, 6, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# # Autoencoder 01: Autoencoder Raso

# %% [markdown]
# ## Definição do Modelo

# %%
encoding_dim = 12

input_img = keras.Input(shape=(784,))
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder01 = keras.Model(input_img, decoded)
autoencoder01.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 12)             │         9,420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 784)            │        10,192 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,612 (76.61 KB)
#  Trainable params: 19,612 (76.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(autoencoder01, show_shapes=True)

# %% [markdown]
# ## Criação dos modelos Encoder e Decoder

# %%
encoder01 = keras.Model(input_img, encoded)

encoded_input = keras.Input(shape=(encoding_dim,))
decoder_layer = autoencoder01.layers[-1]
decoder01 = keras.Model(encoded_input, decoder_layer(encoded_input))

# %% [markdown]
# ## Treinamento do Autoencoder 01

# %%
autoencoder01.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder01.fit(x_train, x_train,
                            epochs=50,
                            batch_size=256,
                            shuffle=True,
                            validation_data=(x_test, x_test),
                            verbose=1) # usar 1 ou 2 para observar a evolucão por época
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.4290 - val_loss: 0.2400
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2248 - val_loss: 0.1918
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1881 - val_loss: 0.1747
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1731 - val_loss: 0.1646
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1641 - val_loss: 0.1597
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1604 - val_loss: 0.1571
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1579 - val_loss: 0.1551
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1560 - val_loss: 0.1534
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1545 - val_loss: 0.1518
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1528 - val_loss: 0.1506
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1515 - val_loss: 0.1495
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1507 - val_loss: 0.1484
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1496 - val_loss: 0.1476
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1489 - val_loss: 0.1468
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1481 - val_loss: 0.1462
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1476 - val_loss: 0.1456
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1471 - val_loss: 0.1452
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1467 - val_loss: 0.1449
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1466 - val_loss: 0.1446
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1460 - val_loss: 0.1446
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1459 - val_loss: 0.1441
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1455 - val_loss: 0.1441
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1455 - val_loss: 0.1439
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1455 - val_loss: 0.1438
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1454 - val_loss: 0.1437
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1447 - val_loss: 0.1436
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1449 - val_loss: 0.1433
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1449 - val_loss: 0.1433
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1449 - val_loss: 0.1432
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1445 - val_loss: 0.1431
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1442 - val_loss: 0.1430
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1444 - val_loss: 0.1429
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1443 - val_loss: 0.1429
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1442 - val_loss: 0.1428
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1444 - val_loss: 0.1428
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1443 - val_loss: 0.1428
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1443 - val_loss: 0.1428
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1441 - val_loss: 0.1426
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1442 - val_loss: 0.1426
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1442 - val_loss: 0.1426
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1443 - val_loss: 0.1425
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1437 - val_loss: 0.1424
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1440 - val_loss: 0.1425
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1437 - val_loss: 0.1424
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1440 - val_loss: 0.1423
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1437 - val_loss: 0.1423
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1437 - val_loss: 0.1423
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1438 - val_loss: 0.1422
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1437 - val_loss: 0.1423
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1436 - val_loss: 0.1422

# %% [markdown]
# ## Avaliação

# %%
decoded_imgs01 = autoencoder01.predict(x_test)

n = 10  # Imagens visualizadas
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Reconstrução
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs01[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
plt.figure()
plt.plot(history.history["loss"], label = "Treino")
plt.plot(history.history["loss"], label = "Validação")
plt.title("Função de Custo")
plt.ylabel("E")
plt.xlabel("Épocas'")
plt.legend()
plt.show()

# %% [markdown]
# ### Projeção com PCA
#
# https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html

# %%
x_test_encoded = encoder01.predict(x_test, batch_size=256)

x_emb = PCA(n_components=2).fit_transform(x_test_encoded)

plt.figure(figsize=(8, 8))
plt.scatter(x_emb[:, 0], x_emb[:, 1], c=y_test, cmap=plt.cm.jet)
plt.colorbar()
plt.show()
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ### Projeção com t-SNE
#
# https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html

# %%
x_emb = TSNE(n_components=2).fit_transform(x_test_encoded)

plt.figure(figsize=(8, 8))
plt.scatter(x_emb[:, 0], x_emb[:, 1], c=y_test, cmap=plt.cm.jet)
plt.colorbar()
plt.show()

# %% [markdown]
# # Autoencoder 02: Autoencoder profundo

# %% [markdown]
# ## Definição do Modelo

# %%
encoding_dim = 12

input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(encoding_dim, activation='relu')(encoded)
decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

autoencoder02 = keras.Model(input_img, decoded)
autoencoder02.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 12)             │           780 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 784)            │       101,136 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 219,804 (858.61 KB)
#  Trainable params: 219,804 (858.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(autoencoder02, show_shapes=True)

# %% [markdown]
# ## Criação dos modelos Encoder e Decoder

# %%
encoder02 = keras.Model(input_img, encoded)

encoded_input = keras.Input(shape=(encoding_dim,))
decoder_layer = autoencoder02.layers[-3] # número de camada da saída até a codificação latente
decoder02 = keras.Model(encoded_input, decoder_layer(encoded_input))

# %% [markdown]
# ## Treinamento do Autoencoder

# %%
autoencoder02.compile(optimizer='adam', loss='binary_crossentropy')

history = autoencoder02.fit(x_train, x_train,
                            epochs=100,
                            batch_size=256,
                            shuffle=True,
                            validation_data=(x_test, x_test),
                            verbose=1) # usar 1 ou 2 para observar a evolucão por época
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.3474 - val_loss: 0.1675
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1618 - val_loss: 0.1462
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1445 - val_loss: 0.1356
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1353 - val_loss: 0.1295
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1305 - val_loss: 0.1263
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1268 - val_loss: 0.1240
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1245 - val_loss: 0.1225
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1231 - val_loss: 0.1206
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1216 - val_loss: 0.1194
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1202 - val_loss: 0.1182
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1190 - val_loss: 0.1170
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1178 - val_loss: 0.1165
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1170 - val_loss: 0.1154
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1160 - val_loss: 0.1147
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1151 - val_loss: 0.1140
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1146 - val_loss: 0.1132
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1136 - val_loss: 0.1124
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1128 - val_loss: 0.1125
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1127 - val_loss: 0.1113
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1120 - val_loss: 0.1109
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1117 - val_loss: 0.1106
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1109 - val_loss: 0.1102
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1106 - val_loss: 0.1099
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1102 - val_loss: 0.1093
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1096 - val_loss: 0.1091
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1094 - val_loss: 0.1089
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1091 - val_loss: 0.1086
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1093 - val_loss: 0.1083
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1087 - val_loss: 0.1083
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1086 - val_loss: 0.1078
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1083 - val_loss: 0.1081
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1080 - val_loss: 0.1077
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1077 - val_loss: 0.1073
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1076 - val_loss: 0.1071
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1072 - val_loss: 0.1071
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1072 - val_loss: 0.1069
# Epoch 37/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1068 - val_loss: 0.1067
# Epoch 38/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1068 - val_loss: 0.1066
# Epoch 39/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1064 - val_loss: 0.1066
# Epoch 40/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1064 - val_loss: 0.1065
# Epoch 41/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1063 - val_loss: 0.1061
# Epoch 42/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1061 - val_loss: 0.1062
# Epoch 43/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1060 - val_loss: 0.1060
# Epoch 44/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1057 - val_loss: 0.1057
# Epoch 45/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1056 - val_loss: 0.1057
# Epoch 46/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1053 - val_loss: 0.1054
# Epoch 47/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1055 - val_loss: 0.1054
# Epoch 48/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1053 - val_loss: 0.1054
# Epoch 49/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1053 - val_loss: 0.1052
# Epoch 50/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1049 - val_loss: 0.1049
# Epoch 51/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1051 - val_loss: 0.1051
# Epoch 52/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1048 - val_loss: 0.1053
# Epoch 53/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1050 - val_loss: 0.1048
# Epoch 54/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1044 - val_loss: 0.1051
# Epoch 55/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1042 - val_loss: 0.1048
# Epoch 56/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1044 - val_loss: 0.1046
# Epoch 57/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1044 - val_loss: 0.1047
# Epoch 58/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1041 - val_loss: 0.1044
# Epoch 59/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1043 - val_loss: 0.1046
# Epoch 60/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1038 - val_loss: 0.1046
# Epoch 61/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1038 - val_loss: 0.1046
# Epoch 62/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1039 - val_loss: 0.1043
# Epoch 63/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1037 - val_loss: 0.1045
# Epoch 64/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1036 - val_loss: 0.1039
# Epoch 65/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1037 - val_loss: 0.1040
# Epoch 66/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1036 - val_loss: 0.1038
# Epoch 67/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1038 - val_loss: 0.1039
# Epoch 68/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1033 - val_loss: 0.1038
# Epoch 69/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1034 - val_loss: 0.1037
# Epoch 70/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1032 - val_loss: 0.1039
# Epoch 71/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1034 - val_loss: 0.1038
# Epoch 72/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1031 - val_loss: 0.1037
# Epoch 73/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1031 - val_loss: 0.1035
# Epoch 74/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1028 - val_loss: 0.1040
# Epoch 75/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1031 - val_loss: 0.1038
# Epoch 76/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1026 - val_loss: 0.1035
# Epoch 77/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1030 - val_loss: 0.1033
# Epoch 78/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1030 - val_loss: 0.1033
# Epoch 79/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1027 - val_loss: 0.1034
# Epoch 80/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1029 - val_loss: 0.1035
# Epoch 81/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1025 - val_loss: 0.1031
# Epoch 82/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1026 - val_loss: 0.1034
# Epoch 83/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1025 - val_loss: 0.1035
# Epoch 84/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1024 - val_loss: 0.1032
# Epoch 85/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1027 - val_loss: 0.1030
# Epoch 86/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1025 - val_loss: 0.1032
# Epoch 87/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1024 - val_loss: 0.1032
# Epoch 88/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1022 - val_loss: 0.1031
# Epoch 89/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1023 - val_loss: 0.1029
# Epoch 90/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1023 - val_loss: 0.1031
# Epoch 91/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1022 - val_loss: 0.1029
# Epoch 92/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1020 - val_loss: 0.1027
# Epoch 93/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1022 - val_loss: 0.1031
# Epoch 94/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1020 - val_loss: 0.1028
# Epoch 95/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1020 - val_loss: 0.1027
# Epoch 96/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1018 - val_loss: 0.1028
# Epoch 97/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1018 - val_loss: 0.1027
# Epoch 98/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1018 - val_loss: 0.1027
# Epoch 99/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1016 - val_loss: 0.1026
# Epoch 100/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1017 - val_loss: 0.1025

# %% [markdown]
# ## Avaliação

# %%
decoded_imgs02 = autoencoder02.predict(x_test)

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(decoded_imgs02[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction (raso)
    ax = plt.subplot(3, n, i + 1 + 2*n)
    plt.imshow(decoded_imgs01[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ### Projeção PCA

# %%
x_test_encoded = encoder02.predict(x_test, batch_size=256)

x_emb = PCA(n_components=2).fit_transform(x_test_encoded)

plt.figure(figsize=(8, 8))
plt.scatter(x_emb[:, 0], x_emb[:, 1], c=y_test, cmap=plt.cm.jet)
plt.colorbar()
plt.show()
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ### Projeção t-SNE

# %%
x_emb = TSNE(n_components=2).fit_transform(x_test_encoded)

plt.figure(figsize=(8, 8))
plt.scatter(x_emb[:, 0], x_emb[:, 1], c=y_test, cmap=plt.cm.jet)
plt.colorbar()
plt.show()

# %% [markdown]
# # Observações sobre o Espaço Latente

# %% [markdown]
# - A dimensão do espaço latente não necessariamente precisa ser menor que a dimensão original
# - Podemos usar autoencoders esparsos para ampliar a dimensionalidade de representação do problema
# - Os autoencoders esparsos demandam algum tipo de regularização para evitar o aprendizado da solução trivial

# %% [markdown]
# # Exercício de Apoio

# %% [markdown]
# ## Utilizando o código acima, substitua as camadas densas por camadas convolucionais.
#
# ### Siga a mesma abordagem utilizada:
#
# 1. Um modelo convolucional raso (apenas um nível convolucional no encoder e um nível no decoder)
# 2. Um modelo convolucional profundo (pelo menos 3 níveis de convolução no encoder e no decoder)
# - Varie o número de filtros em cada nível convolucional
#
# ### Observações:
# - Para as camadas convolucionais do encoder, utilizar: layers.Conv2D
# - Para o decoder: layers.UpSampling2D
# - Ver o exemplo disponível em: https://blog.keras.io/building-autoencoders-in-keras.html
#
# Por fim, reporte os resultados no forum de discussão da semana
